# %% [markdown]
# # Introduction to CUSUM

# %% [markdown]
# # How the likelihood can be rewritten for different distributions

# %% [markdown]
# ## Gaussian

# %% [markdown]
# The distribution is:
# $$p(x_i;\theta)=\frac{1}{\sqrt{2 \pi \sigma^2} }e^{\frac{(x_i - \mu)^2}{2 \sigma ^2}}$$
# Then if the hypothesis are with the following parameters:
# $$\theta_0 = \left[\mu,\sigma \right]$$
# $$\theta_1 = \left[\mu+\delta,\sigma \right]$$
# The log likelihood ratio can be simplified to:
# $$LLR = \frac{\delta}{\sigma^2}\left( x_i - \left(\mu + \frac{\delta}{2}\right)\right)$$

# %% [markdown]
# ## BiGaussian

# %% [markdown]
# The distribution is:
# $$p(x_i;\theta)=\alpha \frac{1}{\sqrt{2 \pi {\sigma_1}^2} }e^{\frac{(x_i - \mu)^2}{2 {\sigma_1}^2}} + (1-\alpha) \frac{1}{\sqrt{2 \pi {\sigma_2}^2} }e^{\frac{(x_i - \mu)^2}{2 {\sigma_2}^2}}$$
# Then if the hypothesis are with the following parameters:
# $$\theta_0 = \left[\mu,\sigma_1,\sigma_2 ,\alpha \right]$$
# $$\theta_1 = \left[\mu+\delta,\sigma_1,\sigma_2,\alpha \right]$$
# The log likelihood cant be simplified.
# $$LLR = \log{\frac{p(x_i;\theta_1)}{p(x_i;\theta_0)}}$$

# %% [markdown]
# ## Gaussian + Laplacian

# %% [markdown]
# ## Approx to bigaussian fast

# %% [markdown]
# $$  p(x_i;\theta)= K_{int} \left\{
#         \begin{array}{ll}
#             \alpha \frac{1}{\sqrt{2 \pi {\sigma_1}^2} }e^{-\frac{(x_i - \mu)^2}{2 {\sigma_1}^2}}  & \quad \lvert x-\mu \rvert \leq x_{cut} \\
#             K_{cont} \frac{1}{\sqrt{2 \pi {\sigma_2}^2} } e^{-\frac{(x_i - \mu)^2}{2 {\sigma_2}^2}} & \quad \lvert x-\mu \rvert \geq x_{cut}
#         \end{array}
#         \right.$$
# where:
# $$x_{cut}: \alpha \frac{1}{\sqrt{2 \pi {\sigma_1}^2} }e^{\frac{{x_{cut}}^2}{2 {\sigma_1}^2}} = (1-\alpha) \frac{1}{\sqrt{2 \pi {\sigma_2}^2} }e^{\frac{{x_{cut}}^2}{2 {\sigma_2}^2}} \iff x_{cut}=\sqrt{\frac{2 {\sigma_1}^2 {\sigma_2}^2 }{{\sigma_2}^2-{\sigma_1}^2} ln\left(\frac{\alpha \sigma_2}{(1-\alpha) \sigma_1} \right) }$$
# $$K_{cont}:K_{cont} \frac{1}{\sqrt{2 \pi {\sigma_2}^2} } e^{-\frac{{x_{cut}}^2}{2 {\sigma_2}^2}} =\alpha \frac{1}{\sqrt{2 \pi {\sigma_1}^2} }e^{-\frac{{x_{cut}}^2}{2 {\sigma_1}^2}} \iff K_{cont}= \alpha \frac{\sigma_2}{\sigma_1} e^{\frac{{x_{cut}}^2}{2}\frac{{\sigma_1}^2-{\sigma_2}^2}{{\sigma_1}^2 {\sigma_2}^2}}$$
# $$K_{int}:  \int_{\inf}^{\inf} p(x_i;\theta) \,dx = 1  \iff K_{int}=\frac{1}{\alpha (1-2 \Phi (\frac{-x_{cut}}{\sigma_1}))+2 K_{cont} \Phi (\frac{-x_{cut}}{\sigma_2})}$$
#
# Then we can express the LLR according to which zone we are:
#
# $$LLR=\left\{
#         \begin{array}{ll}
#             \frac{\delta}{ {\sigma_2}^2} \left(x- \mu -  \frac{\delta}{2} \right)  & \quad x < \mu - x_c \\
#             ln \left(\frac{K_{cont} \sigma_1}{\alpha \sigma_2} \right) + \frac{(x-\mu)^2}{2 {\sigma_1}^2} - \frac{(x-\mu-\delta)^2}{2 {\sigma_2}^2}  & \quad \mu - x_c < x < \mu + x_c \\
#             \frac{\delta}{ {\sigma_2}^2} \left(x- \mu -  \frac{\delta}{2} \right)  & \quad \mu + x_c < x < \mu + \delta - x_c \\
#             ln \left(\frac{\alpha \sigma_2}{K_{cont} \sigma_1} \right) + \frac{(x-\mu)^2}{2 {\sigma_2}^2} - \frac{(x-\mu-\delta)^2}{2 {\sigma_1}^2}  & \quad \mu + \delta - x_c < x < \mu + \delta + x_c \\
#             \frac{\delta}{{\sigma_1}^2} \left(x- \mu -  \frac{\delta}{2} \right) & \quad \mu + \delta - x_c < x < \mu + x_c \\
#             \frac{\delta}{{\sigma_2}^2} \left(x- \mu -  \frac{\delta}{2} \right) & \quad \mu + \delta + x_c < x
#         \end{array}
#         \right.$$
#
# If we call $$K_{LLR}= ln \left(\frac{\alpha \sigma_2}{K_{cont} \sigma_1} \right) $$
# It can be computed before running and save computation time.

# %% [markdown]
# # Analysis

# %%
from funcs_for_notebook import analyze_configuration,estimate_h_range_and_evaluate_for_all_types,estimate_ARL0,gen_bigaussian_noise ##Funcs useful for the notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tests to see the functions working correctly

# %%
from funcs_for_notebook import test_pdfs_and_fits,test_log_likelihoods,test_cusum,test_ARL_estimations
test_pdfs_and_fits();
test_log_likelihoods();
test_cusum();
test_ARL_estimations();
# Out:
# In this case is shown when the expected jump is before the breaking point
# In this case is shown when the expected jump is after the breaking point
# 835
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Traceback (most recent call last):
#
#   File "<ipython-input-5-04b8c58015c3>", line 5, in <module>
#     test_ARL_estimations();
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 306, in test_ARL_estimations
#     ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="Bigaussian")
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 198, in analyze_configuration
#     ARL0_mean_est,ARL0_mean_std_est,ARL0_values,computing_timesARL0=estimate_ARL0(mu,std,std2,alpha,delta,h,noise_generated, pdf_type,tol,base_len, minN)
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 159, in estimate_ARL0
#     idx=idx+res;
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# ARL0 and ARL1 comparison for the different methods, in noise conditions similar to the ones in the devices.

# %% [markdown]
# ## Example on distributions with values of the fitting of devices
# ### Dev 17 Noise setup

# %%
mu=0;alpha=0.91;std=0.013;std2=0.074;  #Dev 17 of day 0709 setup.
mean_current=0.150;
delta= 0.15*mean_current

# %%
h=10; #To try different h values, so the ARL0 are around 50-500 for all configs.
ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="Gaussian",tol=0.01)
print("ARL0:"+str(ARL0_mean_est)+" ARL1: " + str(ARL1_mean_est)+ " Time: " + str(ARL0_comp_time))
# Out:
# ARL0:91.77083333333333 ARL1: 5.946428571428571 Time: 3.5277563314138836e-06

# %%
h=3; #To try different h values, so the ARL0 are around 50-500 for all configs.
ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="PWG",tol=0.01)
print("ARL0:"+str(ARL0_mean_est)+" ARL1: " + str(ARL1_mean_est)+ " Time: " + str(ARL0_comp_time))
#ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="Bigaussian",tol=0.01)
#print("ARL0:"+str(ARL0_mean_est)+" ARL1: " + str(ARL1_mean_est)+ " Time: " + str(ARL0_comp_time))
# Out:
# ARL0:52.26923076923077 ARL1: 1.893939393939394 Time: 5.032751828991554e-06

# %%
n=10
h_values_map={"Gaussian":np.linspace(7,20,num=n),"Bigaussian":np.linspace(2.6,4.8,num=n),"PWG":np.linspace(3,5.3,num=n)}
tol=0.001;
index=0;
res_table=pd.DataFrame(columns = ['pdf type' , 'h', 'ARL0','ARL1','comp_time_per_sample_arl0','ARL0_std','ARL1_std']) 
for pdf_types in h_values_map:
    h_values=h_values_map[pdf_types];
    print("Starting with type " + pdf_types)
    for h in h_values:
        print(str(int(index%n)+1)+"/"+str(n))
        ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type=pdf_types,tol=tol)
        res_table.loc[index]=[pdf_types,h,ARL0_mean_est,ARL1_mean_est,ARL0_comp_time,ARL0_mean_std_est,ARL1_mean_std_est]
        index+=1;
res_table.to_csv("Dev17_ARL_Analysis")
# Out:
# Starting with type Gaussian
# 1/10
# 2/10
# 3/10
# 4/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 5/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 6/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 7/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 8/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 9/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 10/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Starting with type Bigaussian
# 1/10
# 2/10
# 3/10
# 4/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 5/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 6/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 7/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 8/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 9/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 10/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Starting with type PWG
# 1/10
# 2/10
# 3/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 4/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 5/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 6/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 7/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 8/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 9/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# 10/10
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL
# Warning: More noise needed to be generated to have a better estimate of the ARL

# %%
res_table
# Out:
#       pdf type          h  ...  ARL0_std  ARL1_std
# 0     Gaussian   7.000000  ...  0.057080  0.004838
# 1     Gaussian   8.444444  ...  0.070949  0.005821
# 2     Gaussian   9.888889  ...  0.082629  0.006597
# 3     Gaussian  11.333333  ...  0.109628  0.007771
# 4     Gaussian  12.777778  ...  0.139215  0.008445
# 5     Gaussian  14.222222  ...  0.183066  0.009811
# 6     Gaussian  15.666667  ...  0.233176  0.010343
# 7     Gaussian  17.111111  ...  0.295366  0.011108
# 8     Gaussian  18.555556  ...  0.365986  0.012158
# 9     Gaussian  20.000000  ...  0.532793  0.013173
# 10  Bigaussian   2.600000  ...  0.048799  0.002125
# 11  Bigaussian   2.844444  ...  0.075402  0.002354
# 12  Bigaussian   3.088889  ...  0.104212  0.002444
# 13  Bigaussian   3.333333  ...  0.131786  0.002512
# 14  Bigaussian   3.577778  ...  0.169033  0.002667
# 15  Bigaussian   3.822222  ...  0.214725  0.002950
# 16  Bigaussian   4.066667  ...  0.268028  0.003137
# 17  Bigaussian   4.311111  ...  0.331595  0.003371
# 18  Bigaussian   4.555556  ...  0.431832  0.003529
# 19  Bigaussian   4.800000  ...  0.556647  0.003726
# 20         PWG   3.000000  ...  0.059647  0.002360
# 21         PWG   3.255556  ...  0.080882  0.002433
# 22         PWG   3.511111  ...  0.120972  0.002687
# 23         PWG   3.766667  ...  0.155876  0.002760
# 24         PWG   4.022222  ...  0.188994  0.002872
# 25         PWG   4.277778  ...  0.232518  0.003031
# 26         PWG   4.533333  ...  0.295238  0.003381
# 27         PWG   4.788889  ...  0.372868  0.003225
# 28         PWG   5.044444  ...  0.468932  0.003540
# 29         PWG   5.300000  ...  0.602771  0.003791
#
# [30 rows x 7 columns]

# %%
plt.figure(figsize=(14,7))
plt.plot(res_table[res_table["pdf type"]=="Gaussian"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="Gaussian"]["ARL1"].to_numpy(), label="Gaussian approach")
plt.plot(res_table[res_table["pdf type"]=="Bigaussian"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="Bigaussian"]["ARL1"].to_numpy(), label="Bigaussian approach")
plt.plot(res_table[res_table["pdf type"]=="PWG"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="PWG"]["ARL1"].to_numpy(), label="PWG approach")
plt.legend()
plt.xlabel("ARL0")
plt.ylabel("ARL1")
plt.title("Robustness vs detection delay tradeoff for different approaches")
plt.show()

# %% [markdown]
# Gaussian approach needs a higher h to have the same arl0, which forces its ARL1 to increase too. The bigaussian is optimal here, and we can see that the PWG approach has almos the same tradeoff as the optimal one but being much more efficient in the computing. It looks like it has a logarithm shape, so I plot it again with semilogx:

# %%
plt.figure(figsize=(14,7))
plt.semilogx(res_table[res_table["pdf type"]=="Gaussian"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="Gaussian"]["ARL1"].to_numpy(), label="Gaussian approach")
plt.semilogx(res_table[res_table["pdf type"]=="Bigaussian"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="Bigaussian"]["ARL1"].to_numpy(), label="Bigaussian approach")
plt.semilogx(res_table[res_table["pdf type"]=="PWG"]["ARL0"].to_numpy(), res_table[res_table["pdf type"]=="PWG"]["ARL1"].to_numpy(), label="PWG approach")
plt.legend()
plt.xlabel("ARL0")
plt.ylabel("ARL1")
plt.title("Robustness vs detection delay tradeoff for different approaches")
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.semilogy(res_table[res_table["pdf type"]=="Gaussian"]["h"].to_numpy(), res_table[res_table["pdf type"]=="Gaussian"]["ARL0"].to_numpy(), label="Gaussian approach")
plt.semilogy(res_table[res_table["pdf type"]=="Bigaussian"]["h"].to_numpy(), res_table[res_table["pdf type"]=="Bigaussian"]["ARL0"].to_numpy(), label="Bigaussian approach")
plt.semilogy(res_table[res_table["pdf type"]=="PWG"]["h"].to_numpy(), res_table[res_table["pdf type"]=="PWG"]["ARL0"].to_numpy(), label="PWG approach")
plt.legend()
plt.xlabel("h")
plt.ylabel("ARL0")
plt.title("ARL0 as a function of h")
plt.show()

# %% [markdown]
# ### Dev 45

# %%
mu=0;alpha=0.91;std=0.013;std2=0.074; #Fits for dev 45 on 0709 
mean_current=1.03; 
delta= 0.15*mean_current

# %%
h=70; #To try different h values, so the ARL0 are around 50-500 for all configs.
ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="Gaussian",tol=0.01)
print("ARL0:"+str(ARL0_mean_est)+" ARL1: " + str(ARL1_mean_est)+ " Time: " + str(ARL0_comp_time))
# Out:
# ARL0:797.020202020202 ARL1: 1.0 Time: 1.709867315730847e-06

# %%
h=3.5; #To try different h values, so the ARL0 are around 50-500 for all configs.
ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(mu,std,std2,alpha,delta,h,pdf_type="Bigaussian",tol=0.01)
print("ARL0:"+str(ARL0_mean_est)+" ARL1: " + str(ARL1_mean_est)+ " Time: " + str(ARL0_comp_time))
# Out:
# ARL0:249.58415841584159 ARL1: 1.0 Time: 1.3792004832723912e-05

# %% [markdown]
# For this device the expected jumps are so high that having an acceptable ARL we obtain that always ARL1. This can be explained because delta is very high, so one sample with the mean changed already sets the trigger of the jump!

# %% [markdown]
# ## More general analysis

# %%
std_1=1;mu=0;
alphas=[0.6,0.7,0.8,0.9];n_alpha=len(alphas);
std_2s=[3,6,9];n_std_2=len(std_2s);
deltas=[0.5,1,1.5,2,3];n_delta=len(deltas);
target_ARL0_range=[50,500]
tol=0.001;
index=0;
res_table=pd.DataFrame(columns = ['alpha','std2','delta','ARL0_min_big','ARL0_max_big','ARL0_min_g','ARL0_max_g','ARL0_min_pwg','ARL0_max_pwg','h_min_big','h_max_big','h_min_pwg','h_max_pwg','h_min_g','h_max_g']) 
for alpha in alphas:
    for std_2 in std_2s:
        for delta in deltas:
            h_lims_bigauss, h_lims_pwg, h_lims_gauss, ARL0_bigaussian, ARL0_gaussian, ARL0_pwg = estimate_h_range_and_evaluate_for_all_types(mu,std_1,std_2,alpha,delta,target_ARL0_range,verbose=1)
            res_table.loc[index]=[alpha,std_2,delta,ARL0_bigaussian[0],ARL0_bigaussian[1],ARL0_gaussian[0],ARL0_gaussian[1],
                                 ARL0_pwg[0],ARL0_pwg[1], h_lims_bigauss[0],h_lims_bigauss[1],h_lims_pwg[0],h_lims_pwg[1],h_lims_gauss[0],h_lims_gauss[1]]
            index+=1;        
res_table.to_csv("Simple Model H analysis")
# Out:
# Base ARL0 found for bigaussian is :191.6 with H= 2.5
# Hs range for bigaussian are: 1.095712545110812 - 3.106625897882558. R2 val is: 0.9973309354958885
# Base ARL0 found for gaussian is :191.6 with H= 5.0
# Hs range for Gaussian are: 1.9011981437736605 - 6.045572623494261. R2 val is: 0.9999580856333421
# Bigaussian: Min ARL0 got: 33.12444444444444 And max ARL0:509.6012396694215
# Gaussian: Min ARL0 got: 33.946100917431195 And max ARL0:494.8952590959206
# PWG: Min ARL0 got: 29.71020856201976 And max ARL0:387.75646123260435
# Base ARL0 found for bigaussian is :112.6 with H= 2.8000000000000003
# Hs range for bigaussian are: 1.8926976831077977 - 3.9994557437111182. R2 val is: 0.9927879349378078
# Base ARL0 found for gaussian is :112.6 with H= 5.6000000000000005
# Hs range for Gaussian are: 3.2769882207013024 - 8.322175929892719. R2 val is: 0.9988600636636248
# Bigaussian: Min ARL0 got: 43.111111111111114 And max ARL0:460.1524324324324
# Gaussian: Min ARL0 got: 39.075535512965054 And max ARL0:473.19978858350953
# PWG: Min ARL0 got: 38.86806282722513 And max ARL0:374.84232365145226
# Base ARL0 found for bigaussian is :104.04347826086956 with H= 3.0000000000000004
# Hs range for bigaussian are: 2.1717073539960356 - 4.563073512828516. R2 val is: 0.9931076289180579
# Base ARL0 found for gaussian is :104.04347826086956 with H= 6.000000000000001
# Hs range for Gaussian are: 4.242072025746614 - 10.183943635836076. R2 val is: 0.999980424519291
# Bigaussian: Min ARL0 got: 38.63287086446105 And max ARL0:508.9404761904762
# Gaussian: Min ARL0 got: 40.773737373737376 And max ARL0:539.7764952780692
# PWG: Min ARL0 got: 39.41978021978022 And max ARL0:491.6632337796087
# Base ARL0 found for bigaussian is :114.56666666666666 with H= 3.3000000000000007
# Hs range for bigaussian are: 2.5731216325653246 - 4.563600695939061. R2 val is: 0.9968532851426433
# Base ARL0 found for gaussian is :114.56666666666666 with H= 6.600000000000001
# Hs range for Gaussian are: 5.5582456201250094 - 10.776913404868349. R2 val is: 0.9972133993597354
# Bigaussian: Min ARL0 got: 53.11610878661088 And max ARL0:424.89186295503214
# Gaussian: Min ARL0 got: 57.12208067940552 And max ARL0:417.7883650952859
# PWG: Min ARL0 got: 61.44572025052192 And max ARL0:529.0
# Base ARL0 found for bigaussian is :102.73913043478261 with H= 2.8000000000000003
# Hs range for bigaussian are: 2.308839154800577 - 5.622015205863601. R2 val is: 0.9972389924979607
# Base ARL0 found for gaussian is :102.73913043478261 with H= 5.6000000000000005
# Hs range for Gaussian are: 6.356198722617954 - 12.986059089152354. R2 val is: 0.9996208551963662
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Bigaussian: Min ARL0 got: 47.797225186766276 And max ARL0:999.1510934393638
# Gaussian: Min ARL0 got: 47.40714285714286 And max ARL0:471.8482142857143
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# PWG: Min ARL0 got: 55.129883843717 And max ARL0:2670.7784371909
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Hs range for Gaussian are: -1.0897510008150424 - 3.082347060042329. R2 val is: 0.9968973429326973
# Bigaussian: Min ARL0 got: 53.15588914549654 And max ARL0:446.58244111349035
# Gaussian: Min ARL0 got: 1.0 And max ARL0:408.43336944745397
# PWG: Min ARL0 got: 45.81277533039648 And max ARL0:345.98960498960497
# Base ARL0 found for bigaussian is :153.05555555555554 with H= 2.8000000000000003
# Hs range for bigaussian are: 1.7472538898957692 - 3.910822822909161. R2 val is: 0.9996594807183405
# Base ARL0 found for gaussian is :153.05555555555554 with H= 5.6000000000000005
# Hs range for Gaussian are: 0.5922093686906886 - 5.226015998434497. R2 val is: 0.9999963755451207
# Bigaussian: Min ARL0 got: 42.90269151138716 And max ARL0:474.0414201183432
# Gaussian: Min ARL0 got: 11.850225225225225 And max ARL0:489.2025565388397
# PWG: Min ARL0 got: 40.27995642701525 And max ARL0:377.71942446043164
# Base ARL0 found for bigaussian is :106.61538461538461 with H= 2.9000000000000004
# Hs range for bigaussian are: 2.0721524492018286 - 4.529255233619537. R2 val is: 0.9963031234852124
# Base ARL0 found for gaussian is :106.61538461538461 with H= 5.800000000000002
# Hs range for Gaussian are: 1.4299383832610886 - 6.680120190186358. R2 val is: 0.9971291560096203
# Bigaussian: Min ARL0 got: 45.02651933701657 And max ARL0:612.2131147540983
# Gaussian: Min ARL0 got: 21.44812362030905 And max ARL0:520.8255319148936
# PWG: Min ARL0 got: 40.48494623655914 And max ARL0:498.4231943031536
# Base ARL0 found for bigaussian is :100.82608695652173 with H= 2.6
# Hs range for bigaussian are: 2.1192610393987947 - 4.732247723544482. R2 val is: 0.9789807802085516
# Base ARL0 found for gaussian is :100.82608695652173 with H= 5.199999999999999
# Hs range for Gaussian are: 2.8069652036188835 - 7.62409856522886. R2 val is: 0.9999411496027336
# Bigaussian: Min ARL0 got: 34.39589743589744 And max ARL0:627.0128331688055
# Gaussian: Min ARL0 got: 41.23059866962306 And max ARL0:506.0594262295082
# PWG: Min ARL0 got: 31.689892051030423 And max ARL0:553.0357833655706
# Base ARL0 found for bigaussian is :114.9375 with H= 3.2000000000000006
# Hs range for bigaussian are: 2.1628110020884854 - 4.768831749282438. R2 val is: 0.9996866179531114
# Base ARL0 found for gaussian is :114.9375 with H= 6.400000000000001
# Hs range for Gaussian are: 3.634698837221013 - 9.174636204154778. R2 val is: 0.9996398842442719
# Bigaussian: Min ARL0 got: 27.12589559877175 And max ARL0:474.4658753709199
# Gaussian: Min ARL0 got: 41.08758314855876 And max ARL0:487.18768619662364
# PWG: Min ARL0 got: 26.530877573131093 And max ARL0:657.2419028340081
# Base ARL0 found for bigaussian is :228.05 with H= 2.5
# Hs range for bigaussian are: 1.3011779030640727 - 3.214900202106629. R2 val is: 0.9987091852791155
# Base ARL0 found for gaussian is :228.05 with H= 5.0
# Hs range for Gaussian are: 2.4510397456484077 - 7.107164460755078. R2 val is: 0.995477604824704
# Hs range for bigaussian are: 2.7229091855099234 - 3.745655689143731. R2 val is: 0.9011891211801296
# Base ARL0 found for gaussian is :127.77777777777777 with H= 5.800000000000002
# Hs range for Gaussian are: 4.292304901901446 - 13.58411812871486. R2 val is: 0.9988323555023465
# Bigaussian: Min ARL0 got: 47.36510962821735 And max ARL0:178.34012219959266
# Gaussian: Min ARL0 got: 42.60283687943262 And max ARL0:593.5359477124183
# PWG: Min ARL0 got: 47.45292368681863 And max ARL0:186.18996062992127
# Base ARL0 found for bigaussian is :156.88235294117646 with H= 3.800000000000001
# Hs range for bigaussian are: 1.2951938155161649 - 4.5785907190649136. R2 val is: 0.99830993778386
# Base ARL0 found for gaussian is :156.88235294117646 with H= 7.600000000000002
# Hs range for Gaussian are: 5.004198752684342 - 16.67861295485555. R2 val is: 0.9960790608055266
# Bigaussian: Min ARL0 got: 22.25740551583248 And max ARL0:511.03582089552236
# Gaussian: Min ARL0 got: 58.83229813664596 And max ARL0:509.3832046332046
# PWG: Min ARL0 got: 22.24974411463664 And max ARL0:545.8483316481294
# Base ARL0 found for bigaussian is :275.5625 with H= 2.5
# Hs range for bigaussian are: 1.5169296586105427 - 3.4605299831137333. R2 val is: 0.9988232861199285
# Base ARL0 found for gaussian is :275.5625 with H= 5.0
# Hs range for Gaussian are: 2.6970144069264257 - 9.466243840729671. R2 val is: 0.9995912975348314
# Bigaussian: Min ARL0 got: 44.72675736961451 And max ARL0:486.6243654822335
# Gaussian: Min ARL0 got: 42.15555555555556 And max ARL0:500.11178247734136
# PWG: Min ARL0 got: 46.855555555555554 And max ARL0:505.925
# Base ARL0 found for bigaussian is :101.71428571428571 with H= 2.6
# Hs range for bigaussian are: 2.163483614684183 - 4.24828380191754. R2 val is: 0.9811767833649453
# Base ARL0 found for gaussian is :101.71428571428571 with H= 5.199999999999999
# Hs range for Gaussian are: 4.839532442869536 - 13.521744877661071. R2 val is: 0.9998155931542695
# Bigaussian: Min ARL0 got: 48.75555555555555 And max ARL0:470.6446961894954
# Gaussian: Min ARL0 got: 48.47645125958379 And max ARL0:391.3286334056399
# PWG: Min ARL0 got: 53.35356762513312 And max ARL0:495.1132686084142
# Base ARL0 found for bigaussian is :120.6086956521739 with H= 2.7
# Hs range for bigaussian are: 2.296099957631177 - 4.655015736369387. R2 val is: 0.9956792684439226
# Base ARL0 found for gaussian is :120.6086956521739 with H= 5.4
# Hs range for Gaussian are: 6.488053479023152 - 19.517055439905334. R2 val is: 0.9973763854173001
# Bigaussian: Min ARL0 got: 39.60329670329671 And max ARL0:498.98612487611496
# Gaussian: Min ARL0 got: 50.84842105263158 And max ARL0:613.059
# PWG: Min ARL0 got: 42.010893246187365 And max ARL0:521.016016016016
# Base ARL0 found for bigaussian is :107.75 with H= 3.1000000000000005
# Hs range for bigaussian are: 2.7471101626887147 - 3.9684065933892376. R2 val is: 0.9205095623759312
# Base ARL0 found for gaussian is :107.75 with H= 6.200000000000001
# Hs range for Gaussian are: 7.794540465484252 - 25.788812110940178. R2 val is: 0.9999198262394706
# Bigaussian: Min ARL0 got: 53.433439829605966 And max ARL0:238.17482517482517
# Gaussian: Min ARL0 got: 52.273737373737376 And max ARL0:825.6816846229187
# PWG: Min ARL0 got: 57.44318181818182 And max ARL0:260.98558187435634
# Base ARL0 found for bigaussian is :105.15 with H= 3.500000000000001
# Hs range for bigaussian are: 3.0023792496327357 - 4.782172211450476. R2 val is: 0.9997651505609881
# Base ARL0 found for gaussian is :105.15 with H= 7.000000000000002
# Hs range for Gaussian are: 9.692617229131024 - 39.51597648281357. R2 val is: 0.9998962836263771
# Bigaussian: Min ARL0 got: 61.63214990138067 And max ARL0:615.632911392405
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Gaussian: Min ARL0 got: 50.23290598290598 And max ARL0:1646.9123548046462
# PWG: Min ARL0 got: 64.75712881022615 And max ARL0:694.1100099108028
# Base ARL0 found for bigaussian is :140.06666666666666 with H= 2.5
# Hs range for bigaussian are: 1.3071330845833573 - 3.604775119398235. R2 val is: 0.9999491627346948
# Base ARL0 found for gaussian is :140.06666666666666 with H= 5.0
# Hs range for Gaussian are: 2.8858814514927955 - 9.811301000724189. R2 val is: 0.9999761365876749
# Bigaussian: Min ARL0 got: 34.19182746878547 And max ARL0:571.4616161616161
# Gaussian: Min ARL0 got: 45.6207605344296 And max ARL0:366.48369565217394
# PWG: Min ARL0 got: 37.37172177879133 And max ARL0:625.1307456588355
# Base ARL0 found for bigaussian is :100.33333333333333 with H= 3.0000000000000004
# Hs range for bigaussian are: 2.129143755698887 - 4.290018733406952. R2 val is: 0.9850963552657915
# Base ARL0 found for gaussian is :100.33333333333333 with H= 6.000000000000001
# Hs range for Gaussian are: 5.367451420156292 - 16.413126030997383. R2 val is: 0.9899874524853939
# Bigaussian: Min ARL0 got: 45.67705088265836 And max ARL0:486.5414078674948
# Gaussian: Min ARL0 got: 50.743641912512714 And max ARL0:469.7497446373851
# PWG: Min ARL0 got: 48.19027921406411 And max ARL0:547.5528455284552
# Base ARL0 found for bigaussian is :105.36842105263158 with H= 3.2000000000000006
# Hs range for bigaussian are: 2.116880381499752 - 4.8059582908982845. R2 val is: 0.9969840804152198
# Base ARL0 found for gaussian is :105.36842105263158 with H= 6.400000000000001
# Hs range for Gaussian are: 7.241938118156413 - 21.487453879280576. R2 val is: 0.963916274756725
# Bigaussian: Min ARL0 got: 32.73014145810664 And max ARL0:571.575230296827
# Gaussian: Min ARL0 got: 51.243486973947896 And max ARL0:490.78695208970436
# PWG: Min ARL0 got: 36.98618490967056 And max ARL0:650.0069860279441
# Base ARL0 found for bigaussian is :103.28571428571429 with H= 3.2000000000000006
# Hs range for bigaussian are: 2.907219732803466 - 3.9589836522679147. R2 val is: 0.9886481164255636
# Base ARL0 found for gaussian is :103.28571428571429 with H= 6.400000000000001
# Hs range for Gaussian are: 8.72999624235276 - 33.56414197593633. R2 val is: 0.997607414334262
# Bigaussian: Min ARL0 got: 69.69340101522843 And max ARL0:250.03748733535969
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Gaussian: Min ARL0 got: 50.604166666666664 And max ARL0:1215.3858024691358
# PWG: Min ARL0 got: 78.31736526946108 And max ARL0:279.56420626895857
# Base ARL0 found for bigaussian is :100.47058823529412 with H= 3.600000000000001
# Hs range for bigaussian are: 2.726802869733617 - 5.14905123644211. R2 val is: 0.9752987304930022
# Base ARL0 found for gaussian is :100.47058823529412 with H= 7.200000000000002
# Hs range for Gaussian are: 11.894151786334938 - 49.66466423118419. R2 val is: 0.999639686028587
# Bigaussian: Min ARL0 got: 58.603363006923836 And max ARL0:974.8
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Gaussian: Min ARL0 got: 49.788675429727 And max ARL0:2054.1324110671935
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# PWG: Min ARL0 got: 63.863547758284604 And max ARL0:1143.8727272727272

# %%
res_table
# Out:
#     alpha  std2  delta  ...  h_max_pwg    h_min_g    h_max_g
# 0     0.6   3.0    0.5  ...   3.417288   1.901198   6.045573
# 1     0.6   3.0    1.0  ...   4.399401   3.276988   8.322176
# 2     0.6   3.0    1.5  ...   5.019381   4.242072  10.183944
# 3     0.6   3.0    2.0  ...   5.019961   5.558246  10.776913
# 4     0.6   3.0    3.0  ...   6.184217   6.356199  12.986059
# 5     0.6   6.0    0.5  ...   3.368276   0.048545   4.337227
# 6     0.6   6.0    1.0  ...   4.403628   1.864574   6.443985
# 7     0.6   6.0    1.5  ...   4.664194   2.834888   7.876372
# 8     0.6   6.0    2.0  ...   5.014725   3.396062   9.191682
# 9     0.6   6.0    3.0  ...   5.377924   5.128988  10.566460
# 10    0.6   9.0    0.5  ...   3.276213  -1.089751   3.082347
# 11    0.6   9.0    1.0  ...   4.301905   0.592209   5.226016
# 12    0.6   9.0    1.5  ...   4.982181   1.429938   6.680120
# 13    0.6   9.0    2.0  ...   5.205472   2.806965   7.624099
# 14    0.6   9.0    3.0  ...   5.245715   3.634699   9.174636
# 15    0.7   3.0    0.5  ...   3.536390   2.451040   7.107164
# 16    0.7   3.0    1.0  ...   4.416004   4.218122   9.615651
# 17    0.7   3.0    1.5  ...   4.815396   5.404662  11.747338
# 18    0.7   3.0    2.0  ...   5.319145   6.462642  13.751449
# 19    0.7   3.0    3.0  ...   6.936827   7.460568  17.851965
# 20    0.7   6.0    0.5  ...   3.635488   1.279661   5.869092
# 21    0.7   6.0    1.0  ...   4.489620   3.129189   8.218565
# 22    0.7   6.0    1.5  ...   4.886725   4.435135  10.427303
# 23    0.7   6.0    2.0  ...   5.380896   5.357358  12.005380
# 24    0.7   6.0    3.0  ...   5.624253   7.039463  15.110086
# 25    0.7   9.0    0.5  ...   3.582801  -0.440028   4.689282
# 26    0.7   9.0    1.0  ...   4.722166   1.868068   7.240008
# 27    0.7   9.0    1.5  ...   4.965391   2.785107   9.095241
# 28    0.7   9.0    2.0  ...   5.502131   3.670492  10.792754
# 29    0.7   9.0    3.0  ...   4.841827   5.717759  12.667830
# 30    0.8   3.0    0.5  ...   3.609724   2.697637   7.659889
# 31    0.8   3.0    1.0  ...   4.674912   4.171249  10.707852
# 32    0.8   3.0    1.5  ...   5.471301   5.669148  13.080839
# 33    0.8   3.0    2.0  ...   5.504123   6.492721  15.796278
# 34    0.8   3.0    3.0  ...   5.445320   7.153455  18.790233
# 35    0.8   6.0    0.5  ...   3.768725   2.222451   7.913545
# 36    0.8   6.0    1.0  ...   4.406401   4.425061  11.112200
# 37    0.8   6.0    1.5  ...   5.105558   6.164608  14.222321
# 38    0.8   6.0    2.0  ...   5.321153   7.192773  16.339834
# 39    0.8   6.0    3.0  ...   4.227119   9.774386  24.150430
# 40    0.8   9.0    0.5  ...   3.640728   1.413720   6.904056
# 41    0.8   9.0    1.0  ...   4.441035   3.519483  10.706332
# 42    0.8   9.0    1.5  ...   5.240613   5.208488  12.593305
# 43    0.8   9.0    2.0  ...   5.461042   6.154098  15.658669
# 44    0.8   9.0    3.0  ...   5.103526   8.701784  21.260664
# 45    0.9   3.0    0.5  ...   3.750398   2.136047   6.458052
# 46    0.9   3.0    1.0  ...   4.634422   3.795118   8.979198
# 47    0.9   3.0    1.5  ...   5.801254   4.133412  11.309475
# 48    0.9   3.0    2.0  ...   4.120221   4.292305  13.584118
# 49    0.9   3.0    3.0  ...   5.036450   5.004199  16.678613
# 50    0.9   6.0    0.5  ...   3.806583   2.697014   9.466244
# 51    0.9   6.0    1.0  ...   4.673112   4.839532  13.521745
# 52    0.9   6.0    1.5  ...   5.120517   6.488053  19.517055
# 53    0.9   6.0    2.0  ...   4.365247   7.794540  25.788812
# 54    0.9   6.0    3.0  ...   5.260389   9.692617  39.515976
# 55    0.9   9.0    0.5  ...   3.965253   2.885881   9.811301
# 56    0.9   9.0    1.0  ...   4.719021   5.367451  16.413126
# 57    0.9   9.0    1.5  ...   5.286554   7.241938  21.487454
# 58    0.9   9.0    2.0  ...   4.354882   8.729996  33.564142
# 59    0.9   9.0    3.0  ...   5.663956  11.894152  49.664664
#
# [60 rows x 15 columns]

# %%
df = pd.read_csv ('Simple Model H analysis') ## Maybe I can improve the limits interpolating? Nope, didnt work as expected.
def interpolate_h_vals(ARL0_min,ARL0_max,h_min,h_max,ARL_target,hmin=1):
    m=(ARL0_max-ARL0_min)/(h_max-h_min);
    b=ARL0_max-m*h_max;
    h_target_min=(ARL_target[0]-b)/m;
    h_target_max=(ARL_target[1]-b)/m;
    h_target_min = h_target_min if h_target_min > hmin else hmin;
    return h_target_min,h_target_max
target_ARL0_range=[50,500]
noise_len=1e6;
tol=0.001;
for index, row in df.iterrows():
    h_target_min,h_target_max=interpolate_h_vals(row['ARL0_min_big'],row['ARL0_max_big'],row['h_min_big'],row['h_max_big'],target_ARL0_range);
    noise_generated=gen_bigaussian_noise(0,1,row['std2'],row['alpha'],int(noise_len))
    ARL0_bigaussian_min,_,_,_=estimate_ARL0(0,1,row['std2'],row['alpha'],row['delta'],h_target_min,noise_generated, "Bigaussian",tol,noise_len,minN=5)
    ARL0_bigaussian_max,_,_,_=estimate_ARL0(0,1,row['std2'],row['alpha'],row['delta'],h_target_max,noise_generated, "Bigaussian",tol,noise_len,minN=5)
    print("New limits: min " + str(ARL0_bigaussian_min) + " max " + str(ARL0_bigaussian_max))
# Out:
# New limits: min 38.517203107658155 max 484.2746913580247
# New limits: min 49.463146314631466 max 585.5566137566137
# New limits: min 43.131131131131134 max 509.30839231547014
# New limits: min 49.73961499493414 max 681.1626694473409
# New limits: min 51.92154811715481 max 156.53340635268347
# New limits: min 42.91463414634146 max 451.8118393234672
# New limits: min 48.07692307692308 max 537.0202839756593
# New limits: min 50.54507337526206 max 501.9922480620155
# New limits: min 50.717948717948715 max 537.472166998012
# New limits: min 53.750254841997965 max 382.34662576687117
# New limits: min 50.85281385281385 max 551.5163599182005
# New limits: min 43.13601741022851 max 540.9588638589618
# New limits: min 45.795983086680764 max 380.1957773512476
# New limits: min 46.05601659751037 max 358.9560975609756
# New limits: min 30.26372549019608 max 600.8821218074656
# Traceback (most recent call last):
#
#   File "<ipython-input-7-6fe573af1c17>", line 16, in <module>
#     ARL0_bigaussian_max,_,_,_=estimate_ARL0(0,1,row['std2'],row['alpha'],row['delta'],h_target_max,noise_generated, "Bigaussian",tol,noise_len,minN=5)
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 164, in estimate_ARL0
#     res=CUSUM(noise_generated[idx:],delta,h,mu,std_est,LLR_callback=LLR_map[pdf_type],params=params,mode="Return detection sample")
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 101, in CUSUM
#     sp[k] = LLR_callback(signal_in[k],mu,std,delta,*params)
#
#   File "C:\Users\JK-WORK\Documents\CUSUM\funcs_for_notebook.py", line 55, in bigaussian_LLR
#     den=alpha * 1/np.sqrt(2*np.pi*std**2) * np.exp(-(x-mu)**2/(2*std**2))+ (1- alpha) * 1/np.sqrt(2*np.pi*std2**2) * np.exp(-(x-mu)**2/(2*std2**2))
#
# KeyboardInterrupt

# %%
df = pd.read_csv ('Simple Model H analysis') 
noise_len=1e6;
tol=0.001;
n=10;
out_table=pd.DataFrame(columns = ['alpha','std2','delta','pdf_type','h','ARL0','ARL1','CompTime']) 
pdf_types=["Gaussian","Bigaussian","PWG"];
out_table_idx=0;
def get_hs_for_pdf(row,pdf_types):
    if pdf_types=="Gaussian":
        hmin=row['h_min_g'];hmax=row['h_max_g'];
    elif pdf_types=="Bigaussian":
        hmin=row['h_min_big'];hmax=row['h_max_big'];
    elif pdf_types=="PWG":
        hmin=row['h_min_pwg'];hmax=row['h_max_pwg'];
    return hmin,hmax;
for index, row in df.iterrows():
    for pdf_type in pdf_types:
        hmin,hmax=get_hs_for_pdf(row,pdf_type)
        hs=np.linspace(hmin,hmax,num=n)
        for h in hs:
            print(out_table_idx)
            ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(0,1,row['std2'],row['alpha'],row['delta'],h,tol=tol,pdf_type=pdf_type)
            out_table.loc[out_table_idx]=[row['alpha'],row['std2'],row['delta'],pdf_type,h,ARL0_mean_est,ARL1_mean_est,ARL0_comp_time]
            out_table_idx+=1;
out_table.to_csv("ARL_Results_diff_confs.csv")
# Out:
# 0
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 2
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 11
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 12
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 21
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 22
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 23
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 24
# 25
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 26
# 27
# 28
# 29
# 30
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 31
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 32
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 33
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 41
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# 49
# 50
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 51
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 52
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 53
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 61
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 71
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 72
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 81
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 91
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 101
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 131
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 141
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 142
# 143
# 144
# 145
# 146
# 147
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 148
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 149
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 150
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 151
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 152
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 153
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 154
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 155
# 156
# 157
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 158
# 159
# 160
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 161
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 162
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 171
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 172
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 173
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 181
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 182
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 191
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 201
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 202
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 211
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 212
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 221
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 231
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 232
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 241
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 242
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 251
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 261
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 271
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 281
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 291
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 301
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 302
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 303
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 304
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 305
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 306
# 307
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 308
# 309
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 310
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 311
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 312
# 313
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 321
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 322
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 323
# 324
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 325
# 326
# 327
# 328
# 329
# 330
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 331
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 332
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 333
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 341
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 351
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 352
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 361
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 362
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 363
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 371
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 381
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 382
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 391
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 401
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 411
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 421
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 431
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 432
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 441
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 451
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 452
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 461
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 462
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 471
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 472
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 481
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 491
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 501
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 502
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 521
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 522
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 531
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 532
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 533
# 534
# 535
# 536
# 537
# 538
# 539
# 540
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 541
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 542
# 543
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 551
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 552
# 553
# 554
# 555
# 556
# 557
# 558
# 559
# 560
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 578
# 579
# 580
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 581
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 589
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 590
# 591
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 592
# 593
# 594
# 595
# 596
# 597
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 598
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 599
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# Warning: More noise needed to be generated to have a better estimate of the ARL0
# 600
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 601
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 602
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 603
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 611
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 612
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 613
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 621
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 622
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 623
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 631
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 632
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 641
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 642
# Warning: More noise needed to be generated to have a better estimate of the ARL1
# 643
# 644
# 645
# 646

# %%
df = pd.read_csv ('Simple Model H analysis') 
noise_len=1e6;
tol=0.0005;
n=20;
out_table=pd.DataFrame(columns = ['alpha','std2','delta','pdf_type','h','ARL0','ARL1','CompTime']) 
pdf_types=["Gaussian","Bigaussian","PWG"];
out_table_idx=0;
def get_hs_for_pdf(row,pdf_types):
    if pdf_types=="Gaussian":
        hmin=row['h_min_g'];hmax=row['h_max_g'];
    elif pdf_types=="Bigaussian":
        hmin=row['h_min_big'];hmax=row['h_max_big'];
    elif pdf_types=="PWG":
        hmin=row['h_min_pwg'];hmax=row['h_max_pwg'];
    return hmin,hmax;
for index, row in df.iterrows():
    for pdf_type in pdf_types:
        hmin,hmax=get_hs_for_pdf(row,pdf_type)
        hs=np.linspace(hmin,hmax,num=n)
        for h in hs:
            print(out_table_idx)
            ARL0_mean_est,ARL0_mean_std_est,ARL1_mean_est,ARL1_mean_std_est,ARL0_comp_time,ARL1_comp_time=analyze_configuration(0,1,row['std2'],row['alpha'],row['delta'],h,tol=tol,pdf_type=pdf_type)
            out_table.loc[out_table_idx]=[row['alpha'],row['std2'],row['delta'],pdf_type,h,ARL0_mean_est,ARL1_mean_est,ARL0_comp_time]
            out_table_idx+=1;
out_table.to_csv("ARL_Results_diff_confs_higher_res.csv")
